# %%
import pandas as pd # Needed for data processing
import numpy as np
import texthero as hero # Needed for data cleaning
from texthero import preprocessing
from nltk.corpus import stopwords # Needed for stopwords
from HanTa import HanoverTagger as ht # Needed for lemmatization
from nltk.tokenize import word_tokenize # Needed for tokenization
import pickle # Needed for object export
import sys # Needed for system settings
from sklearn.feature_extraction.text import TfidfVectorizer # Needed for NLP TF-IDF algorithm
from sklearn.metrics.pairwise import cosine_similarity # Needed for cosine similarity

pd.set_option('display.max_rows', 50)
np.set_printoptions(threshold = sys.maxsize)

hannover = ht.HanoverTagger("morphmodel_ger.pgz") # Needed for German lemmatization

# %%
df = pd.read_csv("../data/processed_data.csv", encoding="utf-8")

# %%
# Creates empty variable
token_stop = []
# # Defines symbols and other common terms that add no information gain to the algorithm (to clean user input)
characters = ["z.B.", "(", ")", ":", ".", ",", "|", "*", "&", "+", " I ", " II ", " III ", " IV ", " V ", " VI ", " x ", "\x96", "Semester", "ECTS", "Bachelorarbeit", "Abschlussarbeit", "Bachelor", "Studium", "Grundlagen", "Wochen", "Auslandssemester", "Berufspraktikum", "Wahlfach"]

# Defines tokenization and lemmatization function
def tokenizer_lemmatizer(text, stopwords = token_stop, lemmatize = True, user_input = False):
    
    # Cleans data if it is user input, else skips this step
    if user_input:
        for i in range(len(characters)):
            text = text.replace(characters[i], "")
        text = text.replace("/", " ")
        text = text.replace("-", " ")
        
    # Lemmatizes data using the hannover.analyze lemmatization model for German language, else only tokenizes
    if lemmatize:
        tokens = [hannover.analyze(w)[0] for w in word_tokenize(text)]
    else:
        tokens = [w for w in word_tokenize(text)]
    tokens = [w for w in tokens if w not in stopwords]
    
    return(tokens)

# %%
# Imports preprocessed pickle objects
vectorizer = pickle.load(open("../data/vectorizer.pkl", "rb")) 
tfidf_mat = pickle.load(open("../data/tfidf_mat.pkl", "rb")) 
token_stop = pickle.load(open("../data/stopwords.pkl", "rb"))

# %%
# Defines indices extraction function
def extract_best_indices(m, topk, mask = None):
    # returns the sum on all tokens of cosinus for each sentence
    if len(m.shape) > 1:
        cos_sim = np.mean(m, axis = 0) 
    else: 
        cos_sim = m
    index = np.argsort(cos_sim)[::-1] # from highest index to smallest score
    similarities = np.sort(cos_sim)[::-1]
    
    if mask is not None:
        assert mask.shape == m.shape
        mask = mask[index]
    else:
        mask = np.ones(len(cos_sim))
        
    mask = np.logical_or(cos_sim[index] != 0, mask) # eliminates cosine distance of 0
    best_index = index[mask][:topk]
    best = similarities[mask][:topk]
    
    return best_index, best

# %%
# Defines cosine similarity function
def get_recommendations_tfidf(query, tfidf_mat):
    # Embeds the query sentence
    tokens_query = [str(tok).lower() for tok in tokenizer_lemmatizer(text = query, user_input = True)]
    embed_query = vectorizer.transform(tokens_query)
    
    # Creates list with similarity between query and dataset
    mat = cosine_similarity(embed_query, tfidf_mat)

    # Best cosine distance for each token independently
    best_index = extract_best_indices(mat, topk = len(df.index))[0]
    best = extract_best_indices(mat, topk = len(df.index))[1]
    return best_index, best

# %%
# Defines main function
def studybuddy(user_input, n_results):
    best_index = get_recommendations_tfidf(query = user_input, tfidf_mat = tfidf_mat)[0]
    best = get_recommendations_tfidf(query = user_input, tfidf_mat = tfidf_mat)[1]
    best = [round(n, 2) for n in best]

    # Creates columns similarity and rank for datatable return
    results = df.iloc[best_index]
    results.insert(2, "similarity", best)
    results.insert(0, 'rank', range(1, len(results) + 1))
    results = results[:n_results]
    
    # Exports results as pickle
    results.to_pickle("results.pkl")
    
    return results

# %%
# Example recommendation based on user input - can be played around with
studybuddy("Data Science Machine Learning Künstliche Intelligenz", n_results = 25)
# Out:
#       rank  major_id  is_list  similarity  \
# 1973     1      2048     True        0.19
# 1962     2      2037     True        0.16
# 1979     3      2054     True        0.15
# 1978     4      2053     True        0.15
# 1967     5      2042     True        0.13
# 1951     6      2026    False        0.13
# 1977     7      2052     True        0.12
# 474      8       502     True        0.11
# 1970     9      2045     True        0.11
# 2031    10      2106     True        0.11
# 680     11       717     True        0.10
# 1972    12      2047     True        0.10
# 1241    13      1298     True        0.10
# 1971    14      2046     True        0.10
# 1981    15      2056     True        0.10
# 1976    16      2051     True        0.09
# 1950    17      2025    False        0.09
# 2040    18      2116     True        0.08
# 1563    19      1627     True        0.08
# 1968    20      2043     True        0.08
# 245     21       259     True        0.07
# 749     22       791     True        0.07
# 2013    23      2088     True        0.07
# 65      24        68     True        0.07
# 25      25        26     True        0.07
#
#                                              major_name  \
# 1973                          Data Science & Management
# 1962                   Computational Business Analytics
# 1979                                       Data Science
# 1978                                       Data Science
# 1967                    Data Engineering and Consulting
# 1951            Künstliche Intelligenz und Data Science
# 1977             Business Intelligence and Data Science
# 474                                  Business Analytics
# 1970                                 Business Analytics
# 2031                             Künstliche Intelligenz
# 680   Industrial Engineering and International Manag...
# 1972                  Data Science & Business Analytics
# 1241  Industrial Engineering and International Manag...
# 1971                            Business Data Analytics
# 1981                                       Data Science
# 1976           Business Intelligence and Data Analytics
# 1950   Angewandte Informatik und Künstliche Intelligenz
# 2040                    Applied Artificial Intelligence
# 1563  Wirtschaftsingenieurwesen - Digital Production...
# 1968                      Big Data & Business Analytics
# 245      Management & Technology – Digital Technologies
# 749      Management & Technology – Digital Technologies
# 2013                                         Informatik
# 65                  Medizin- und Gesundheitstechnologie
# 25                           Digital Health Engineering
#
#                                                    text  \
# 1973  data science management informatik mathematik ...
# 1962  computational business analytics informatik ma...
# 1979  data science informatik mathematik informatik ...
# 1978  data science informatik mathematik informatik ...
# 1967  data engineering and consulting informatik mat...
# 1951  künstliche intelligenz und data science inform...
# 1977  business intelligence and data science informa...
# 474   business analytics wirtschaft recht betriebswi...
# 1970  business analytics informatik mathematik infor...
# 2031  künstliche intelligenz informatik mathematik i...
# 680   industrial engineering and international manag...
# 1972  data science business analytics informatik mat...
# 1241  industrial engineering and international manag...
# 1971  business data analytics informatik mathematik ...
# 1981  data science informatik mathematik informatik ...
# 1976  business intelligence and data analytics infor...
# 1950  angewandte informatik und künstliche intellige...
# 2040  applied artificial intelligence informatik mat...
# 1563  wirtschaftsingenieurwesen digital production m...
# 1968  big data business analytics informatik mathema...
# 245   management technology – digital technologies m...
# 749   management technology – digital technologies w...
# 2013  informatik informatik mathematik informatik in...
# 65    medizin und gesundheitstechnologie medizin ges...
# 25    digital health engineering medizin gesundheits...
#
#                                       major_description  \
# 1970                    https://hs-aalen.de/courses/108
# 2031  https://www.thi.de/studium/studienangebote/det...
# 680   https://www.hs-fresenius.de/studium/industrial...
# 1972  https://dbuas.de/studiengang/data-science-busi...
# 1241  https://www.hs-fresenius.de/studium/industrial...
# 1971  https://www.fhdw-hannover.de/de/master-und-pro...
# 1981               https://www.hs-harz.de/data-science/
# 1976  https://www.hs-emden-leer.de/studierende/studi...
# 1950  https://www.umwelt-campus.de/studium/studienan...
# 2040  https://www.th-rosenheim.de/technik/informatik...
# 1563  https://www.hs-albsig.de/studienangebot/master...
# 1968  https://www.fom.de/studiengaenge/it-management...
# 245   https://www.wi.tum.de/programs/bachelor-in-man...
# 749   https://www.wi.tum.de/programs/bachelor-in-man...
# 2013  https://www.tu-clausthal.de/studieninteressier...
# 65    https://www.th-owl.de/eecs/studium/studienange...
# 25    https://www.hs-fresenius.de/studium/digital-he...
#
#                         category  ...                    major_category  \
# 1973     Informatik & Mathematik  ...  Datenanalyse und Datenmanagement
# 1962     Informatik & Mathematik  ...                  Computer Science
# 1979     Informatik & Mathematik  ...                 Datenwissenschaft
# 1978     Informatik & Mathematik  ...                 Datenwissenschaft
# 1967     Informatik & Mathematik  ...            Data & Web Engineering
# 1951     Informatik & Mathematik  ...             Angewandte Informatik
# 1977     Informatik & Mathematik  ...                 Datenwissenschaft
# 474           Wirtschaft & Recht  ...           Business Administration
# 1970     Informatik & Mathematik  ...  Datenanalyse und Datenmanagement
# 2031     Informatik & Mathematik  ...                        Informatik
# 680           Wirtschaft & Recht  ...          International Management
# 1972     Informatik & Mathematik  ...  Datenanalyse und Datenmanagement
# 1241    Technik & Ingenieurwesen  ...            Industrial Engineering
# 1971     Informatik & Mathematik  ...  Datenanalyse und Datenmanagement
# 1981     Informatik & Mathematik  ...                 Datenwissenschaft
# 1976     Informatik & Mathematik  ...                 Datenwissenschaft
# 1950     Informatik & Mathematik  ...             Angewandte Informatik
# 2040     Informatik & Mathematik  ...              Intelligente Systeme
# 1563    Technik & Ingenieurwesen  ...         Wirtschaftsingenieurwesen
# 1968     Informatik & Mathematik  ...  Datenanalyse und Datenmanagement
# 245       Medien & Kommunikation  ...                   Digitale Medien
# 749           Wirtschaft & Recht  ...                        Management
# 2013     Informatik & Mathematik  ...                        Informatik
# 65    Medizin & Gesundheitswesen  ...         Gesundheitswissenschaften
# 25    Medizin & Gesundheitswesen  ...                          E-Health
#
#                                              university  \
# 1973  DBU Digital Business University of Applied Sci...
# 1962           Frankfurt School of Finance & Management
# 1979                                   Hochschule Aalen
# 1978                          XU Exponential University
# 1967                    Hochschule Albstadt-Sigmaringen
# 1951                                   Hochschule Trier
# 1977           ISM - International School of Management
# 474                                    Hochschule Aalen
# 1970                                   Hochschule Aalen
# 2031                   Technische Hochschule Ingolstadt
# 680                                Hochschule Fresenius
# 1972  DBU Digital Business University of Applied Sci...
# 1241                               Hochschule Fresenius
# 1971  Fachhochschule für die Wirtschaft Hannover (FHDW)
# 1981                                    Hochschule Harz
# 1976                              Hochschule Emden/Leer
# 1950                                   Hochschule Trier
# 2040                    Technische Hochschule Rosenheim
# 1563                    Hochschule Albstadt-Sigmaringen
# 1968                                     FOM Hochschule
# 245                                    TUM - TU München
# 749                                    TUM - TU München
# 2013                                       TU Clausthal
# 65             Technische Hochschule Ostwestfalen-Lippe
# 25                                 Hochschule Fresenius
#
#                         location degree_type           degree_label  language  \
# 1973                      Berlin       M.Sc.      Master of Science   Deutsch
# 1962           Frankfurt am Main       B.Sc.    Bachelor of Science  Englisch
# 1979                       Aalen       B.Sc.    Bachelor of Science   Deutsch
# 1978                     Potsdam       B.Sc.    Bachelor of Science  Englisch
# 1967                    Albstadt       M.Sc.      Master of Science   Deutsch
# 1951                       Trier       M.Sc.      Master of Science   Deutsch
# 1977                 4 Standorte       M.Sc.      Master of Science  Englisch
# 474                        Aalen       B.Sc.    Bachelor of Science   Deutsch
# 1970                       Aalen       B.Sc.    Bachelor of Science   Deutsch
# 2031                  Ingolstadt       B.Sc.    Bachelor of Science   Deutsch
# 680                  2 Standorte      M.Eng.  Master of Engineering  Englisch
# 1972  Berlin & Digitales Studium       B.Sc.    Bachelor of Science   Deutsch
# 1241                 2 Standorte      M.Eng.  Master of Engineering  Englisch
# 1971                    Hannover       M.Sc.      Master of Science   Deutsch
# 1981                 Wernigerode       M.Sc.      Master of Science   Deutsch
# 1976                       Emden      M.Eng.  Master of Engineering  Englisch
# 1950      Hoppstädten-Weiersbach       B.Sc.    Bachelor of Science   Deutsch
# 2040                   Rosenheim       B.Sc.    Bachelor of Science  Englisch
# 1563                    Albstadt       M.Sc.      Master of Science   Deutsch
# 1968                15 Standorte       M.Sc.      Master of Science   Deutsch
# 245                  2 Standorte       B.Sc.    Bachelor of Science  Englisch
# 749                  2 Standorte       B.Sc.    Bachelor of Science  Englisch
# 2013        Clausthal-Zellerfeld       B.Sc.    Bachelor of Science   Deutsch
# 65                         Lemgo       B.Sc.    Bachelor of Science   Deutsch
# 25                   2 Standorte       B.Sc.    Bachelor of Science   Deutsch
#
#      duration_of_study rating_amount  rating  recommendation_rate
# 1973        4 Semester           1.0     4.7                 1.00
# 1962        7 Semester           3.0     4.7                 1.00
# 1979        7 Semester           5.0     4.3                 0.80
# 1978        6 Semester           0.0     NaN                  NaN
# 1967    3 - 5 Semester           4.0     4.3                 1.00
# 1951        4 Semester           NaN     NaN                  NaN
# 1977    3 - 4 Semester           2.0     4.8                 1.00
# 474         7 Semester           0.0     NaN                  NaN
# 1970        7 Semester           0.0     NaN                  NaN
# 2031        7 Semester          10.0     4.4                 1.00
# 680         4 Semester           2.0     4.6                 1.00
# 1972        6 Semester           NaN     4.6                  NaN
# 1241        4 Semester           2.0     4.6                 1.00
# 1971        7 Quartale           NaN     NaN                  NaN
# 1981    3 - 5 Semester           0.0     NaN                  NaN
# 1976    3 - 5 Semester           0.0     NaN                  NaN
# 1950        7 Semester           1.0     4.0                 1.00
# 2040        7 Semester           1.0     3.0                 1.00
# 1563    3 - 5 Semester          43.0     4.2                 0.98
# 1968        5 Semester           3.0     4.3                 1.00
# 245         6 Semester          25.0     4.1                 0.88
# 749         6 Semester          25.0     4.1                 0.88
# 2013        6 Semester           7.0     4.0                 0.86
# 65          6 Semester          20.0     3.8                 1.00
# 25          6 Semester           0.0     NaN                  NaN
#
# [25 rows x 21 columns]
